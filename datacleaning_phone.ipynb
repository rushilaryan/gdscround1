# %%
import pandas as pd

# %%
po=pd.read_csv("FinalData.csv")

# %%
po.dropna(inplace=True)
po = po.dropna() 
po
# Out:
#      Unnamed: 0                                               Name    Price  \
# 0             0  SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)  (4...   ₹9,799
# 1             1  SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)  (4...   ₹9,799
# 2             2  SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)  (4...   ₹9,799
# 3             3         REDMI 10 (Pacific Blue, 64 GB)  (4 GB RAM)   ₹9,999
# 4             4                APPLE iPhone 13 (Starlight, 128 GB)  ₹58,999
# ..          ...                                                ...      ...
# 219         219  OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)...  ₹21,962
# 220         220  SAMSUNG Galaxy F14 5G (B.A.E. Purple, 128 GB) ...  ₹14,490
# 221         221       vivo T1X (Gravity Black, 128 GB)  (6 GB RAM)  ₹14,999
# 222         222          vivo T1X (Space Blue, 128 GB)  (4 GB RAM)  ₹12,999
# 223         223          vivo T1X (Space Blue, 128 GB)  (6 GB RAM)  ₹14,999
#
# ...

# %%
po["Price"] = po["Price"].str.replace('[\₹\,\.]', '').astype(int)
# Out:
# C:\Users\rushi\AppData\Local\Temp\ipykernel_1452\369258008.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   po["Price"] = po["Price"].str.replace('[\₹\,\.]', '').astype(int)

# %%
dataMapping={
    "1 Year": 1,
    "0": 0,
    "12 Month": 1,
    "2 Year": 2,
    '16.76 cm (6.6 inch)':16.76,
    '17.02 cm (6.7 inch)':17.02,
    '15.49 cm (6.1 inch)':15.49,
    '17.07 cm (6.72 inch)':17.07,
    '16.51 cm (6.5 inch)':16.51,
    '4.5 cm (1.77 inch)':4.5,
    '17.04 cm (6.71 inch)':17.04,
    '16.64 cm (6.55 inch)':16.64,
    '16.56 cm (6.52 inch)':16.56,
    '17.32 cm (6.82 inch)':17.32,
    '16.71 cm (6.58 inch)':16.71,
    '16.26 cm (6.4 inch)':16.26,
    '16.33 cm (6.43 inch)':16.33,
    '17.22 cm (6.78 inch)':17.22, 
    '15.6 cm (6.14 inch)':15.6,
    '16.94 cm (6.67 inch)':16.94,
    '16.59 cm (6.53 inch)':16.59,
    '6.1 cm (2.4 inch)':6.1, 
    '5.08 cm (2 inch)':5.08,
    '4.57 cm (1.8 inch)':4.57,
    '7.11 cm (2.8 inch)':7.11,
    '17.22 cm (6.78 Inch)':17.22,
    '16.74 cm (6.59 inch)':16.74,
    '16.66 cm (6.56 inch)':16.66,
    'Dual Sim':2,
    'Single Sim':1,
    'Dual Sim(Nano + eSIM)':3,
    'Yes':1,
    'No':0,
    '2408 x 1080 Pixels':2600640,
    '1650 x 720 Pixels':1188000, 
    '2532 x 1170 Pixels':296010,
    '1792 x 828 Pixels':1483776,
    '2400 x 1080 Pixels':2592000, 
    '1600 x 720 Pixel':1152000,
    '160 x 128 Pixels':20480,
    '2460 x 1080 Pixels':2656800, 
    '2400 x 1080 Pixel':2592000,
    '1600 x 720 Pixels':1152000,
    '720 X 1640 Pixels':1180800, 
    '1640 x 720 Pixels':1180800,
    '2400 x 1080 PIxels':2592000,
    '1600 x720 Pixels':1152000,
    '240x320$$Pixels':76800,
    '128 x 160 Pixels':20480,
    '320 x 240$$Pixels':76800,
    '320 x 240 Pixels':76800,
    '160 x 128$$pixel':20480,
    '1080 x 2408 Pixels':2211840,
    '128 x 160$$Pixels':20480,
    '320 x 240$$pixel':76800,
    '240 x 320$$pixel':76800,
    '240x320':76800,
    '2400 × 1080 Pixels':2592000,
    '320x240 Pixels':76800,
    '2412 x 1080 Pixels':2604960,
    '128*160':20480,
    '1612 x 720 Pixels':1160640,
    '1600X700 Pixels':1120000,
    '320 x 480$$Pixels':153600,
    '1080x2400 Pixels':259200,
    '2400x1080 Pixels':259200,
    'Android 12':12,
    'Android 11':11,#ios system
    'iOS 15':25,
    'iOS 14.2':24.2,
    'Android 13':13,
    'Symbian':1,
    'Android 12 Go':22.5,
    'Android 13 (Go Edition)':23.5, 
    'Android 10':10,  
    'RTOS':2,
    'Series 30+':3,
    'Android':11,
    'iOS 16':26,
    'Octa Core':8,
    'Hexa Core':6,
    'Quad Core':4,
    'Single Core':1,
    '2 GHz':2,
    '2.4 GHz':2.4, 
    '1.82 GHz':1.82,
    '0.208 GHz':0.208,
    '2.2 GHz':2.2,
    '2.3 GHz':2.3,
    '1.6 GHz':1.6,
    '2.05 GHz':2.05,
     '2.8 GHz':2.8, 
    '1.8 GHz':1.8,
    '1.8 MHz':0.000018,
       '2.6 GHz':2.6,
    '208 MHz':0.00208, 
    '1 MHz' :0.00001,
    '1 GHz':1,
    '1.2 MHz':0.000012,
    '2.2 MHz':0.000022,
    '64 GB':64,
    '128 GB':128,
    '32 GB':32, 
    '32 MB':0.032,
    '4 MB':0.004,
    '0 GB':0,
    '128 MB':0.128,
    '0 MB':0.0, 
    '3 MB':0.003, 
    '64 MB':0.064,
    '256 GB':256,
    '207 g':207,
    '203 g':203, 
    '173 g':173, 
    '194 g':194,
    '189.5 g':189.5,
    '205 g':205, 
    '182 g':182,
    '51 g':51,
    '192 g':192,
    '169 g':169, 
    '180 g':180,
    '184 g':184,
    '190 g':190,
    '210 g':210,
    '200 g':200,
    '195 g':195,
    '179.5 g':179.5,
    '220 g':220,
    '198 g':198,
    '186 g':186,
    '188 g':188,
    '187 g':187,
    '181 g':181,
    '74.98 g':74.98,
    '204 g':204, 
    '109 g':109, 
    '110 g':110,
    '90.5 g':90.5,
    '91.3 g':91.3,
    '201 g':201,
    '81.9 g':81.9,
    '189 g':189,
    '172 g':172,
    '72 g':72,
    '6000 mAh':6000,
    '5000 mAh':5000,
    '800 mAh':800, 
    '1000 mAh':1000,
    '1750 mAh':1750,
    '2500 mAh':2500,
    '1020 mAh':1020,
    '4600 mAh':4600,
    '620 mAh':620, 
    '400 mAh':400,
    '3.5mm':1,
    '3.5 mm':1,
    '3.5':1,
    '4G, 3G, 2G':432,
    '4G VOLTE, 4G, 3G, 2G':4432,
    '5G, 4G, 3G, 2G':5432,
    '2G, 3G, 4G':432, 
    '2G, 3G, 4G, 5G':5432,
    '2G':2,
    '5G, 4G VOLTE, 4G, 3G, 2G':54432,
    '2G, 3G, 4G, 4G VOLTE':4432,
    '4G':4, 
    '5G':5,
    '2G, 3G, 4G, 4G VOLTE, 5G':54432,
    '4G VOLTE':44,
    '1':1,
    '0':0,
    '50MP + 5MP + 2MP':57,
    '50MP + 2MP':52,
    'Call Wait/Hold':3,
    'Video Call Support':2,
    'Speaker Phone':4,
    '12MP + 12MP':24,
    '64MP + 2MP':66,
    '8MP Rear Camera':8,
    '50MP Rear Camera':50,
    '50MP + 8MP + 2MP':60,
    '108MP + 2MP':110, 
    '8MP Dual Camera':16, 
    'Network Type':5,
    '13Mp + AI Lens':113,
    '50MP + 8MP':58,
    '13MP Rear Camera':13,
    '64MP + 8MP + 2MP':74,
    'Phone Book':6,
    'Hands Free':8,
    '50 MP + 2 MP + QVGA':102,
    '13MP + 2MP + 2MP':17,
    '50MP (OIS) + 8MP + 2MP':85,
    '50MP + 2MP + 2MP':54,
    '0.3MP Rear Camera':0.3,
    '50MP + AI Lens':150, 
    '1.3MP Rear Camera':1.3,
    '50MP + 2MP Depth Sensor + 2MP Macro Sensor':90,
    '64MP Rear Camera':64,
    '50MP + 0.3MP + 0.3MP':50.6, 
    '48MP + 8MP + 2MP':58,
    '108MP + 2MP (Depth) + 2MP (Macro)':112,
    '8MP Front Camera':80,
    '5MP Front Camera':50, 
    '12MP Front Camera':120,
    '13MP Front Camera':130,
    '0MP Front Camera':0,
    '16MP Front Camera':160,
    '0.3MP Front Camera':0.3,
    '50MP Front Camera':50,
    '4 GB':4,
    '8 GB':8,
    '6 GB':6,
    '2 GB':2,
    '32 MB':0.00032,
    '3 GB':3,
    '4 MB':0.0004,
    '64 MB':0.0064
}

# %%
po["Display Size"]=po["Display Size"].map(dataMapping)
po["SIM Type"]=po["SIM Type"].map(dataMapping)
po["Touchscreen"]=po["Touchscreen"].map(dataMapping)
po["Resolution"]=po["Resolution"].map(dataMapping)
po["Operating System"]=po["Operating System"].map(dataMapping)
po["Processor Core"]=po["Processor Core"].map(dataMapping)


po["Primary Clock Speed"]=po["Primary Clock Speed"].map(dataMapping)
po["Internal Storage"]=po["Internal Storage"].map(dataMapping)

# %%
po["Primary Camera"].unique()
# Out:
# array(['50MP + 5MP + 2MP', '50MP + 2MP', 'Call Wait/Hold',
#        'Video Call Support', 'Speaker Phone', '12MP + 12MP', '64MP + 2MP',
#        '8MP Rear Camera', '50MP Rear Camera', '50MP + 8MP + 2MP',
#        '108MP + 2MP', '8MP Dual Camera', 'Network Type', '13Mp + AI Lens',
#        '50MP + 8MP', '13MP Rear Camera', '64MP + 8MP + 2MP', 'Phone Book',
#        'Hands Free', '50 MP + 2 MP + QVGA', '13MP + 2MP + 2MP',
#        '50MP (OIS) + 8MP + 2MP', '50MP + 2MP + 2MP', '0.3MP Rear Camera',
#        '50MP + AI Lens', '1.3MP Rear Camera',
#        '50MP + 2MP Depth Sensor + 2MP Macro Sensor', '64MP Rear Camera',
#        '50MP + 0.3MP + 0.3MP', '48MP + 8MP + 2MP',
#        '108MP + 2MP (Depth) + 2MP (Macro)'], dtype=object)

# %%
po["RAM"].unique()
# Out:
# array(['4 GB', '8 GB', '6 GB', '2 GB', '32 MB', '3 GB', '4 MB', '64 MB'],
#       dtype=object)

# %%
po
# Out:
#      Unnamed: 0                                               Name  Price  \
# 0             0  SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)  (4...   9799
# 1             1  SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)  (4...   9799
# 2             2  SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)  (4...   9799
# 3             3         REDMI 10 (Pacific Blue, 64 GB)  (4 GB RAM)   9999
# 4             4                APPLE iPhone 13 (Starlight, 128 GB)  58999
# ..          ...                                                ...    ...
# 219         219  OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)...  21962
# 220         220  SAMSUNG Galaxy F14 5G (B.A.E. Purple, 128 GB) ...  14490
# 221         221       vivo T1X (Gravity Black, 128 GB)  (6 GB RAM)  14999
# 222         222          vivo T1X (Space Blue, 128 GB)  (4 GB RAM)  12999
# 223         223          vivo T1X (Space Blue, 128 GB)  (6 GB RAM)  14999
#
#      Model Name           Color  SIM Type  Touchscreen  Display Size  \
# ...

# %%
po["Domestic Warranty"]=po["Domestic Warranty"].map(dataMapping)
po["Weight"]=po["Weight"].map(dataMapping)
po["Battery Capacity"]=po["Battery Capacity"].map(dataMapping)
po["GPS Support"]=po["GPS Support"].map(dataMapping)

# %%
po["Audio Jack"]=po["Audio Jack"].map(dataMapping)#yes or no
po["Wi-Fi"]=po["Wi-Fi"].map(dataMapping)
po["Bluetooth Support"]=po["Bluetooth Support"].map(dataMapping)
po["Full HD Recording"]=po["Full HD Recording"].map(dataMapping)

po["Network Type"]=po["Network Type"].map(dataMapping)

# %%
po.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 189 entries, 0 to 223
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  189 non-null    int64
#  1   Name                        189 non-null    object
#  2   Price                       189 non-null    int32
#  3   Model Name                  189 non-null    object
#  4   Color                       189 non-null    object
#  5   SIM Type                    189 non-null    float64
#  6   Touchscreen                 189 non-null    float64
#  7   Display Size                189 non-null    float64
#  8   Resolution                  189 non-null    float64
#  9   Operating System            189 non-null    float64
#  10  Processor Core              189 non-null    float64
#  11  Primary Clock Speed         189 non-null    float64
#  12  Internal Storage            189 non-null    float64
# ...

# %%
po["Primary Camera Available"]=po["Primary Camera Available"].map(dataMapping)
po["Secondary Camera Available"]=po["Secondary Camera Available"].map(dataMapping)

# %%
po["Primary Camera"]
# Out:
# 0      57.0
# 1      57.0
# 2      57.0
# 3      52.0
# 4       3.0
#        ...
# 219     4.0
# 220     3.0
# 221     5.0
# 222     5.0
# 223     5.0
# Name: Primary Camera, Length: 189, dtype: float64

# %%
po["Primary Camera"]=po["Primary Camera"].map(dataMapping)
po["Secondary Camera"]=po["Secondary Camera"].map(dataMapping)

# %%
po["RAM"]=po["RAM"].map(dataMapping)

# %%
po
# Out:
#      Unnamed: 0                                               Name  Price  \
# 0             0  SAMSUNG Galaxy F13 (Nightsky Green, 64 GB)  (4...   9799
# 1             1  SAMSUNG Galaxy F13 (Sunrise Copper, 64 GB)  (4...   9799
# 2             2  SAMSUNG Galaxy F13 (Waterfall Blue, 64 GB)  (4...   9799
# 3             3         REDMI 10 (Pacific Blue, 64 GB)  (4 GB RAM)   9999
# 4             4                APPLE iPhone 13 (Starlight, 128 GB)  58999
# ..          ...                                                ...    ...
# 219         219  OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)...  21962
# 220         220  SAMSUNG Galaxy F14 5G (B.A.E. Purple, 128 GB) ...  14490
# 221         221       vivo T1X (Gravity Black, 128 GB)  (6 GB RAM)  14999
# 222         222          vivo T1X (Space Blue, 128 GB)  (4 GB RAM)  12999
# 223         223          vivo T1X (Space Blue, 128 GB)  (6 GB RAM)  14999
#
#      Model Name           Color  SIM Type  Touchscreen  Display Size  \
# ...

# %%
po.to_csv("Final.csv")
